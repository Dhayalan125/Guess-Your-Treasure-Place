# %%
#ex=[0,1,3,4,5,6]
from random import shuffle
#r=shuffle(ex)
#print(r)
def shuffle_list(mylist):
    shuffle(mylist)
    return mylist
#result= shuffle_list(ex)
#print(result)
mylist=[" ","Gold"," "]
shuffle_list(mylist)



#player guess 
def player_guess():
    guess = ""
    while guess not in ["0","1","2"]:
        guess = input('Gues the right place to collect your Treasure in the Place 0, 1 or 2 : ')
    return int(guess)
s=player_guess()
print("---------------------")

#check guess
def check_guess(mylist,s):
    if mylist[s] == "Gold":
        print('Your guess is correct')
    else:
        print("ohhh It's wrong.Good lock for your next guess...")
        print("---------------------")
        e = "Gold"
        k = mylist.index(e)
        print("The index of treasure is :", k)
print(check_guess(mylist,s))
# Out:
# Gues the right place to collect your Treasure in the Place 0, 1 or 2 :  1
# ---------------------
# Your guess is correct
# None
